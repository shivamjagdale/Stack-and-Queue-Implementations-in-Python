# %%
# Queue implementation using List in Python

def enqueue():
    n = int(input("Write the element you want to be inserted :- "))
    queue.append(n)
    
def dequeue():
    if len(queue)==0:
        print("Cant delete anything cause the queue is empty")
    else:
        print(queue[0], " has been deleted")
        del queue[0]
    print("\n")    

def display():
    if len(queue)==0:
        print("Can't display anything cause the queue is empty")
    else:
        print("The elements in the queue are :- ")
        for element in queue:
            print(element, end=" ")
        print("\nFront of the queue is ", queue[0])
        print("Rear of the queue is ", queue[-1])
        print("\n")    

queue = list()

while(1):
    print("Choose from the menu \n1-Enqueue Operation \n2-Dequeue Operation \n3-Display Operation \n Press any key to exit")
    
    str = input()
    
    if str=="1":
        print("Enqueue Operation")
        enqueue()
    
    elif str=="2":
        print("Dequeue Operation")
        dequeue()
        
    elif str=="3":
        print("Display Operation")
        display()
    
    else:
        print("You have exited from the program")
        break
# Out:
# Choose from the menu
# 1-Enqueue Operation
# 2-Dequeue Operation
# 3-Display Operation
#  Press any key to exit
# 1
# Enqueue Operation
# Write the element you want to be inserted :- 10
# Choose from the menu
# 1-Enqueue Operation
# 2-Dequeue Operation
# 3-Display Operation
#  Press any key to exit
# 1
# Enqueue Operation
# Write the element you want to be inserted :- 20
# Choose from the menu
# 1-Enqueue Operation
# 2-Dequeue Operation
# 3-Display Operation
#  Press any key to exit
# 1
# Enqueue Operation
# Write the element you want to be inserted :- 30
# Choose from the menu
# 1-Enqueue Operation
# 2-Dequeue Operation
# 3-Display Operation
#  Press any key to exit
# 1
# Enqueue Operation
# Write the element you want to be inserted :- 40
# Choose from the menu
# 1-Enqueue Operation
# 2-Dequeue Operation
# 3-Display Operation
#  Press any key to exit
# 3
# Display Operation
# The elements in the queue are :-
# 10 20 30 40
# Front of the queue is  10
# Rear of the queue is  40
#
#
# ...
