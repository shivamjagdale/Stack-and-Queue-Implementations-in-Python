# %%
# Stack Implementation using lists in Python. 
# Stack Operations (Push, Pop)

def push():
    n = int(input("Enter the element to be inserted in the stack. "))
    
    if len(stack)==0:
        stack.append(n)
    else:
        stack.insert(0,n)
    print(n, "Element is inserted into stack")    
    

def pop():
    if len(stack)==0:
        print("The stack is empty.")
    else:
        print(stack[0], " is deleted from stack")
        del stack[0]
        
def display():
    if len(stack)==0:
        print("The stack is empty")
    else:
        print("The elements of the stack are")
        for element in stack:
            print(element)
        print("Top of the stack is ", stack[0])    
    
stack = list()

while(1):
    print("Enter the operation from below \n 1-Push Operation \n 2-Pop Operation \n 3-Display Operation \n Enter any key to exit")
    str = input()
    
    if str=="1":
        print("Push Operation")
        push()
        
    elif str=="2":
        print("Pop Operation")
        pop()
        
    elif str=="3":
        print("Display Operation")
        display()
        
    else:
        print("Exit from porgram")
        break
# Out:
# Enter the operation from below
#  1-Push Operation
#  2-Pop Operation
#  3-Display Operation
#  Enter any key to exit
# 1
# Push Operation
# Enter the element to be inserted in the stack. 10
# 10 Element is inserted into stack
# Enter the operation from below
#  1-Push Operation
#  2-Pop Operation
#  3-Display Operation
#  Enter any key to exit
# 1
# Push Operation
# Enter the element to be inserted in the stack. 20
# 20 Element is inserted into stack
# Enter the operation from below
#  1-Push Operation
#  2-Pop Operation
#  3-Display Operation
#  Enter any key to exit
# 3
# The elements of the stack are
# 20
# 10
# Top of the stack is  20
# Enter the operation from below
#  1-Push Operation
#  2-Pop Operation
#  3-Display Operation
#  Enter any key to exit
# 1
# Push Operation
# Enter the element to be inserted in the stack. 30
# 30 Element is inserted into stack
# Enter the operation from below
#  1-Push Operation
#  2-Pop Operation
#  3-Display Operation
#  Enter any key to exit
# ...
